# %%
# Dependencies 
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import random
from citipy import citipy
from datetime import datetime 
from config import weather_api_key
import requests
import time
from scipy.stats import linregress
import gmaps
from config import g_key

# %%
# Create list for weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Create basic url for API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes in a list.
coordinates = list(lat_lngs)

# %%
# import the citipy module.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities=[]
#Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    #If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for weather map API call.
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Loop through city Lists 
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 
    if (i % 50 == 0 and i >= 50):
        set_count += 1 
        record_count = 1 
    
    # Create URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log URL, set, and record numbers for each city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    record_count += 1

# Make an API request for each city 
    try:
       
        # Parse the JSON data
        city_weather = requests.get(city_url).json()

        # Compile needed data
        city_city = city.title()
        city_country = city_weather['sys']['country']
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_hum = city_weather['main']['humidity']
        city_cloud = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_desc = city_weather['weather'][0]['description']

        # Fill City Data list 
        city_data.append({"City": city_city,
                         "Country": city_country,
                         "Date": city_date,
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_hum,
                         "Cloudiness": city_cloud,
                         "Wind Speed": city_wind,
                         "Current Description": city_desc,
                         })
        
    #If an error occurs
    except: 
        print("City not found. Skipping")
        pass

    # Complete Data Retrieval    
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | kuito
# Processing Record 2 of Set 1 | butaritari
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | sao filipe
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | bengkulu
# Processing Record 8 of Set 1 | clyde river
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | kaitangata
# Processing Record 14 of Set 1 | tautira
# Processing Record 15 of Set 1 | anchorage
# Processing Record 16 of Set 1 | gairatganj
# Processing Record 17 of Set 1 | vila
# Processing Record 18 of Set 1 | le port
# Processing Record 19 of Set 1 | nouadhibou
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | aasiaat
# Processing Record 22 of Set 1 | ituverava
# Processing Record 23 of Set 1 | roma
# Processing Record 24 of Set 1 | panji
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | barranca
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | poum
# Processing Record 32 of Set 1 | nishihara
# Processing Record 33 of Set 1 | naantali
# Processing Record 34 of Set 1 | kamenka
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | gamba
# Processing Record 38 of Set 1 | lebu
# Processing Record 39 of Set 1 | mocuba
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping
# Processing Record 41 of Set 1 | xiongzhou
# Processing Record 42 of Set 1 | puerto ayora
# Processing Record 43 of Set 1 | caravelas
# Processing Record 44 of Set 1 | anavra
# Processing Record 45 of Set 1 | kawalu
# Processing Record 46 of Set 1 | nikolskoye
# Processing Record 47 of Set 1 | chokurdakh
# Processing Record 48 of Set 1 | mareeba
# Processing Record 49 of Set 1 | georgetown
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | bonthe
# Processing Record 2 of Set 2 | yar-sale
# Processing Record 3 of Set 2 | los llanos de aridane
# Processing Record 4 of Set 2 | sambava
# Processing Record 5 of Set 2 | khatanga
# Processing Record 6 of Set 2 | castro
# Processing Record 7 of Set 2 | taolanaro
# City not found. Skipping
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | evensk
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | mys shmidta
# City not found. Skipping
# Processing Record 14 of Set 2 | khani
# Processing Record 15 of Set 2 | tanout
# Processing Record 16 of Set 2 | barentsburg
# City not found. Skipping
# Processing Record 17 of Set 2 | inongo
# Processing Record 18 of Set 2 | saldanha
# Processing Record 19 of Set 2 | mehamn
# Processing Record 20 of Set 2 | bourail
# Processing Record 21 of Set 2 | xiamen
# Processing Record 22 of Set 2 | souillac
# Processing Record 23 of Set 2 | hermanus
# Processing Record 24 of Set 2 | roebourne
# Processing Record 25 of Set 2 | barcelos
# Processing Record 26 of Set 2 | janauba
# Processing Record 27 of Set 2 | rio grande
# Processing Record 28 of Set 2 | sola
# Processing Record 29 of Set 2 | kodiak
# Processing Record 30 of Set 2 | yellowknife
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | provideniya
# Processing Record 33 of Set 2 | bowen
# Processing Record 34 of Set 2 | avarua
# Processing Record 35 of Set 2 | vaini
# Processing Record 36 of Set 2 | rindal
# Processing Record 37 of Set 2 | umzimvubu
# City not found. Skipping
# Processing Record 38 of Set 2 | mar del plata
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | new norfolk
# Processing Record 41 of Set 2 | greenville
# Processing Record 42 of Set 2 | vasto
# Processing Record 43 of Set 2 | krivosheino
# Processing Record 44 of Set 2 | airai
# Processing Record 45 of Set 2 | kavieng
# Processing Record 46 of Set 2 | sarangani
# Processing Record 47 of Set 2 | viligili
# City not found. Skipping
# Processing Record 48 of Set 2 | lolua
# City not found. Skipping
# Processing Record 49 of Set 2 | karratha
# Processing Record 50 of Set 2 | ponta do sol
# Processing Record 1 of Set 3 | smithers
# Processing Record 2 of Set 3 | ahipara
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping
# Processing Record 4 of Set 3 | bolgatanga
# Processing Record 5 of Set 3 | kokkola
# Processing Record 6 of Set 3 | amderma
# City not found. Skipping
# Processing Record 7 of Set 3 | gornopravdinsk
# Processing Record 8 of Set 3 | nueva londres
# Processing Record 9 of Set 3 | marechal candido rondon
# Processing Record 10 of Set 3 | asau
# Processing Record 11 of Set 3 | fortuna
# Processing Record 12 of Set 3 | ixtapa
# Processing Record 13 of Set 3 | dolores
# Processing Record 14 of Set 3 | beaverlodge
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | pangoa
# Processing Record 17 of Set 3 | grand gaube
# Processing Record 18 of Set 3 | guatire
# Processing Record 19 of Set 3 | bathsheba
# Processing Record 20 of Set 3 | ambodifototra
# City not found. Skipping
# Processing Record 21 of Set 3 | narsaq
# Processing Record 22 of Set 3 | saint-francois
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | ahuimanu
# Processing Record 25 of Set 3 | dickson
# Processing Record 26 of Set 3 | karaul
# City not found. Skipping
# Processing Record 27 of Set 3 | itarema
# Processing Record 28 of Set 3 | comodoro rivadavia
# Processing Record 29 of Set 3 | petropavlovka
# Processing Record 30 of Set 3 | marawi
# Processing Record 31 of Set 3 | ostrovnoy
# Processing Record 32 of Set 3 | bethel
# Processing Record 33 of Set 3 | soma
# Processing Record 34 of Set 3 | pietersburg
# Processing Record 35 of Set 3 | grand river south east
# City not found. Skipping
# Processing Record 36 of Set 3 | barra dos coqueiros
# Processing Record 37 of Set 3 | zhigalovo
# Processing Record 38 of Set 3 | beloha
# Processing Record 39 of Set 3 | esperance
# Processing Record 40 of Set 3 | puerto madero
# Processing Record 41 of Set 3 | santa maria
# Processing Record 42 of Set 3 | cidreira
# Processing Record 43 of Set 3 | kudahuvadhoo
# Processing Record 44 of Set 3 | sao jose da coroa grande
# Processing Record 45 of Set 3 | mahebourg
# Processing Record 46 of Set 3 | thohoyandou
# Processing Record 47 of Set 3 | vasilyevskiy mokh
# Processing Record 48 of Set 3 | vaitupu
# City not found. Skipping
# Processing Record 49 of Set 3 | pogar
# Processing Record 50 of Set 3 | simbahan
# Processing Record 1 of Set 4 | cherskiy
# Processing Record 2 of Set 4 | santa isabel
# Processing Record 3 of Set 4 | miles city
# Processing Record 4 of Set 4 | cartagena del chaira
# Processing Record 5 of Set 4 | grass valley
# Processing Record 6 of Set 4 | ijaki
# City not found. Skipping
# Processing Record 7 of Set 4 | santa cruz del sur
# Processing Record 8 of Set 4 | longyearbyen
# Processing Record 9 of Set 4 | victoria
# Processing Record 10 of Set 4 | hilo
# Processing Record 11 of Set 4 | manado
# Processing Record 12 of Set 4 | zhicheng
# Processing Record 13 of Set 4 | pagudpud
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping
# Processing Record 15 of Set 4 | ilulissat
# Processing Record 16 of Set 4 | aykhal
# Processing Record 17 of Set 4 | port lincoln
# Processing Record 18 of Set 4 | port hedland
# Processing Record 19 of Set 4 | dikson
# Processing Record 20 of Set 4 | durham
# Processing Record 21 of Set 4 | barrow
# Processing Record 22 of Set 4 | mayumba
# Processing Record 23 of Set 4 | yabrud
# Processing Record 24 of Set 4 | andenes
# Processing Record 25 of Set 4 | haines junction
# Processing Record 26 of Set 4 | japura
# Processing Record 27 of Set 4 | hannibal
# Processing Record 28 of Set 4 | aljezur
# Processing Record 29 of Set 4 | vila velha
# Processing Record 30 of Set 4 | jutai
# Processing Record 31 of Set 4 | maarianhamina
# Processing Record 32 of Set 4 | vostok
# Processing Record 33 of Set 4 | puerto ayacucho
# Processing Record 34 of Set 4 | churapcha
# Processing Record 35 of Set 4 | ondjiva
# Processing Record 36 of Set 4 | qaanaaq
# Processing Record 37 of Set 4 | angoche
# Processing Record 38 of Set 4 | sisimiut
# Processing Record 39 of Set 4 | fort nelson
# Processing Record 40 of Set 4 | mosquera
# Processing Record 41 of Set 4 | sorland
# Processing Record 42 of Set 4 | ebolowa
# Processing Record 43 of Set 4 | xining
# Processing Record 44 of Set 4 | vila franca do campo
# Processing Record 45 of Set 4 | tuatapere
# Processing Record 46 of Set 4 | beringovskiy
# Processing Record 47 of Set 4 | vaitape
# Processing Record 48 of Set 4 | yomitan
# City not found. Skipping
# Processing Record 49 of Set 4 | nanakuli
# Processing Record 50 of Set 4 | lensk
# Processing Record 1 of Set 5 | buqayq
# City not found. Skipping
# Processing Record 2 of Set 5 | afua
# Processing Record 3 of Set 5 | bousso
# Processing Record 4 of Set 5 | honiara
# Processing Record 5 of Set 5 | busselton
# Processing Record 6 of Set 5 | ancud
# Processing Record 7 of Set 5 | eluru
# Processing Record 8 of Set 5 | pulandian
# Processing Record 9 of Set 5 | owando
# Processing Record 10 of Set 5 | lompoc
# Processing Record 11 of Set 5 | sao joao da barra
# Processing Record 12 of Set 5 | port hardy
# Processing Record 13 of Set 5 | senanga
# Processing Record 14 of Set 5 | sur
# Processing Record 15 of Set 5 | kloulklubed
# Processing Record 16 of Set 5 | touros
# Processing Record 17 of Set 5 | tibati
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | cayenne
# Processing Record 20 of Set 5 | bengbu
# Processing Record 21 of Set 5 | kilindoni
# Processing Record 22 of Set 5 | samusu
# City not found. Skipping
# Processing Record 23 of Set 5 | portland
# Processing Record 24 of Set 5 | la paz
# Processing Record 25 of Set 5 | kincardine
# Processing Record 26 of Set 5 | kruisfontein
# Processing Record 27 of Set 5 | ambovombe
# Processing Record 28 of Set 5 | altay
# Processing Record 29 of Set 5 | iskateley
# Processing Record 30 of Set 5 | okara
# Processing Record 31 of Set 5 | mpanda
# Processing Record 32 of Set 5 | sibolga
# Processing Record 33 of Set 5 | christchurch
# Processing Record 34 of Set 5 | melville
# Processing Record 35 of Set 5 | kaseda
# Processing Record 36 of Set 5 | awjilah
# Processing Record 37 of Set 5 | saskylakh
# Processing Record 38 of Set 5 | kefamenanu
# Processing Record 39 of Set 5 | torbay
# Processing Record 40 of Set 5 | isangel
# Processing Record 41 of Set 5 | boende
# Processing Record 42 of Set 5 | dumas
# Processing Record 43 of Set 5 | kashi
# Processing Record 44 of Set 5 | bacungan
# Processing Record 45 of Set 5 | praya
# Processing Record 46 of Set 5 | saleaula
# City not found. Skipping
# Processing Record 47 of Set 5 | iqaluit
# Processing Record 48 of Set 5 | gedo
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | oranjemund
# Processing Record 1 of Set 6 | visnes
# Processing Record 2 of Set 6 | garowe
# Processing Record 3 of Set 6 | tsihombe
# City not found. Skipping
# Processing Record 4 of Set 6 | lahij
# Processing Record 5 of Set 6 | alta
# Processing Record 6 of Set 6 | nizhneyansk
# City not found. Skipping
# Processing Record 7 of Set 6 | merauke
# Processing Record 8 of Set 6 | hofn
# Processing Record 9 of Set 6 | mataro
# Processing Record 10 of Set 6 | half moon bay
# Processing Record 11 of Set 6 | itaituba
# Processing Record 12 of Set 6 | east london
# Processing Record 13 of Set 6 | myitkyina
# Processing Record 14 of Set 6 | talara
# Processing Record 15 of Set 6 | salalah
# Processing Record 16 of Set 6 | waipawa
# Processing Record 17 of Set 6 | tasiilaq
# Processing Record 18 of Set 6 | port elizabeth
# Processing Record 19 of Set 6 | asosa
# Processing Record 20 of Set 6 | sitka
# Processing Record 21 of Set 6 | lavrentiya
# Processing Record 22 of Set 6 | lagoa
# Processing Record 23 of Set 6 | fioletovo
# Processing Record 24 of Set 6 | bambous virieux
# Processing Record 25 of Set 6 | iralaya
# Processing Record 26 of Set 6 | kasongo-lunda
# Processing Record 27 of Set 6 | megion
# Processing Record 28 of Set 6 | thompson
# Processing Record 29 of Set 6 | uwayl
# City not found. Skipping
# Processing Record 30 of Set 6 | wawa
# Processing Record 31 of Set 6 | robertsport
# Processing Record 32 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 33 of Set 6 | san cristobal
# Processing Record 34 of Set 6 | muroto
# Processing Record 35 of Set 6 | kamenskoye
# City not found. Skipping
# Processing Record 36 of Set 6 | tiarei
# Processing Record 37 of Set 6 | csakvar
# Processing Record 38 of Set 6 | katima mulilo
# Processing Record 39 of Set 6 | cabo san lucas
# Processing Record 40 of Set 6 | luganville
# Processing Record 41 of Set 6 | erenhot
# Processing Record 42 of Set 6 | victoria falls
# Processing Record 43 of Set 6 | nanortalik
# Processing Record 44 of Set 6 | constitucion
# Processing Record 45 of Set 6 | pontivy
# Processing Record 46 of Set 6 | taburi
# City not found. Skipping
# Processing Record 47 of Set 6 | leshukonskoye
# Processing Record 48 of Set 6 | praia
# Processing Record 49 of Set 6 | turan
# Processing Record 50 of Set 6 | monticello
# Processing Record 1 of Set 7 | mamakan
# Processing Record 2 of Set 7 | eureka
# Processing Record 3 of Set 7 | vardo
# Processing Record 4 of Set 7 | bugojno
# Processing Record 5 of Set 7 | riverton
# Processing Record 6 of Set 7 | tiksi
# Processing Record 7 of Set 7 | jardim
# Processing Record 8 of Set 7 | smirnykh
# Processing Record 9 of Set 7 | harlingen
# Processing Record 10 of Set 7 | innisfail
# Processing Record 11 of Set 7 | kota belud
# Processing Record 12 of Set 7 | antofagasta
# Processing Record 13 of Set 7 | sudbury
# Processing Record 14 of Set 7 | namatanai
# Processing Record 15 of Set 7 | mitzic
# Processing Record 16 of Set 7 | liverpool
# Processing Record 17 of Set 7 | dibulla
# Processing Record 18 of Set 7 | ulladulla
# Processing Record 19 of Set 7 | keti bandar
# Processing Record 20 of Set 7 | mogadishu
# Processing Record 21 of Set 7 | puerto rico
# Processing Record 22 of Set 7 | panguna
# Processing Record 23 of Set 7 | humaita
# Processing Record 24 of Set 7 | pastavy
# Processing Record 25 of Set 7 | bahia honda
# Processing Record 26 of Set 7 | hekinan
# Processing Record 27 of Set 7 | lorengau
# Processing Record 28 of Set 7 | sembe
# Processing Record 29 of Set 7 | batabano
# Processing Record 30 of Set 7 | sungairaya
# Processing Record 31 of Set 7 | florianopolis
# Processing Record 32 of Set 7 | zalantun
# Processing Record 33 of Set 7 | hamilton
# Processing Record 34 of Set 7 | geraldton
# Processing Record 35 of Set 7 | chicama
# Processing Record 36 of Set 7 | binzhou
# Processing Record 37 of Set 7 | kahului
# Processing Record 38 of Set 7 | pisco
# Processing Record 39 of Set 7 | sumbuya
# Processing Record 40 of Set 7 | buala
# Processing Record 41 of Set 7 | quatre cocos
# Processing Record 42 of Set 7 | aberfoyle
# Processing Record 43 of Set 7 | pevek
# Processing Record 44 of Set 7 | kirensk
# Processing Record 45 of Set 7 | ekhabi
# Processing Record 46 of Set 7 | husavik
# Processing Record 47 of Set 7 | trinidad
# Processing Record 48 of Set 7 | nelson
# Processing Record 49 of Set 7 | quelimane
# Processing Record 50 of Set 7 | urumqi
# Processing Record 1 of Set 8 | hasaki
# Processing Record 2 of Set 8 | krasnoselkup
# Processing Record 3 of Set 8 | joshimath
# Processing Record 4 of Set 8 | hirara
# Processing Record 5 of Set 8 | karema
# Processing Record 6 of Set 8 | kalmunai
# Processing Record 7 of Set 8 | ust-kamchatsk
# City not found. Skipping
# Processing Record 8 of Set 8 | tidore
# City not found. Skipping
# Processing Record 9 of Set 8 | pierre
# Processing Record 10 of Set 8 | bartica
# Processing Record 11 of Set 8 | namibe
# Processing Record 12 of Set 8 | coahuayana
# Processing Record 13 of Set 8 | reni
# Processing Record 14 of Set 8 | carballo
# Processing Record 15 of Set 8 | solnechnyy
# Processing Record 16 of Set 8 | kerrville
# Processing Record 17 of Set 8 | marathon
# Processing Record 18 of Set 8 | sabha
# Processing Record 19 of Set 8 | skibbereen
# Processing Record 20 of Set 8 | cape coast
# Processing Record 21 of Set 8 | faanui
# Processing Record 22 of Set 8 | toliary
# City not found. Skipping
# Processing Record 23 of Set 8 | aguimes
# Processing Record 24 of Set 8 | marcona
# City not found. Skipping
# Processing Record 25 of Set 8 | maragogi
# Processing Record 26 of Set 8 | tiznit
# Processing Record 27 of Set 8 | ariquemes
# Processing Record 28 of Set 8 | maldonado
# Processing Record 29 of Set 8 | rudnichnyy
# Processing Record 30 of Set 8 | dieppe bay
# City not found. Skipping
# Processing Record 31 of Set 8 | taoudenni
# Processing Record 32 of Set 8 | nguiu
# City not found. Skipping
# Processing Record 33 of Set 8 | conde
# Processing Record 34 of Set 8 | tarudant
# City not found. Skipping
# Processing Record 35 of Set 8 | houston
# Processing Record 36 of Set 8 | flinders
# Processing Record 37 of Set 8 | shimoda
# Processing Record 38 of Set 8 | fethiye
# Processing Record 39 of Set 8 | balikpapan
# Processing Record 40 of Set 8 | la paz centro
# Processing Record 41 of Set 8 | severo-kurilsk
# Processing Record 42 of Set 8 | port blair
# Processing Record 43 of Set 8 | chifeng
# Processing Record 44 of Set 8 | champerico
# Processing Record 45 of Set 8 | north bend
# Processing Record 46 of Set 8 | tevaitoa
# Processing Record 47 of Set 8 | karpathos
# Processing Record 48 of Set 8 | tromso
# Processing Record 49 of Set 8 | troitskoye
# Processing Record 50 of Set 8 | belaya gora
# Processing Record 1 of Set 9 | green valley
# Processing Record 2 of Set 9 | rawson
# Processing Record 3 of Set 9 | ambon
# Processing Record 4 of Set 9 | sawtell
# Processing Record 5 of Set 9 | salinas
# Processing Record 6 of Set 9 | luocheng
# Processing Record 7 of Set 9 | russell
# Processing Record 8 of Set 9 | bilma
# Processing Record 9 of Set 9 | plattling
# Processing Record 10 of Set 9 | pribelskiy
# City not found. Skipping
# Processing Record 11 of Set 9 | great falls
# Processing Record 12 of Set 9 | ossora
# Processing Record 13 of Set 9 | bonavista
# Processing Record 14 of Set 9 | nocupetaro
# Processing Record 15 of Set 9 | malwan
# City not found. Skipping
# Processing Record 16 of Set 9 | komatipoort
# Processing Record 17 of Set 9 | luderitz
# Processing Record 18 of Set 9 | tocopilla
# Processing Record 19 of Set 9 | lerwick
# Processing Record 20 of Set 9 | whitehorse
# Processing Record 21 of Set 9 | baykit
# Processing Record 22 of Set 9 | sakakah
# Processing Record 23 of Set 9 | eyl
# Processing Record 24 of Set 9 | kholmogory
# Processing Record 25 of Set 9 | macau
# Processing Record 26 of Set 9 | pinheiro machado
# Processing Record 27 of Set 9 | mezen
# Processing Record 28 of Set 9 | havre-saint-pierre
# Processing Record 29 of Set 9 | tura
# Processing Record 30 of Set 9 | ripoll
# Processing Record 31 of Set 9 | abha
# Processing Record 32 of Set 9 | korla
# Processing Record 33 of Set 9 | sobolevo
# Processing Record 34 of Set 9 | santa fe
# Processing Record 35 of Set 9 | siderno
# Processing Record 36 of Set 9 | ishigaki
# Processing Record 37 of Set 9 | portobelo
# Processing Record 38 of Set 9 | taree
# Processing Record 39 of Set 9 | flin flon
# Processing Record 40 of Set 9 | wanning
# Processing Record 41 of Set 9 | banganapalle
# Processing Record 42 of Set 9 | goure
# Processing Record 43 of Set 9 | zharkent
# Processing Record 44 of Set 9 | vidim
# Processing Record 45 of Set 9 | northam
# Processing Record 46 of Set 9 | vicuna
# Processing Record 47 of Set 9 | okhotsk
# Processing Record 48 of Set 9 | basco
# Processing Record 49 of Set 9 | floro
# Processing Record 50 of Set 9 | bonnyville
# Processing Record 1 of Set 10 | west wendover
# Processing Record 2 of Set 10 | saint anthony
# Processing Record 3 of Set 10 | shingu
# Processing Record 4 of Set 10 | cockburn town
# Processing Record 5 of Set 10 | gizo
# Processing Record 6 of Set 10 | coquimbo
# Processing Record 7 of Set 10 | attawapiskat
# City not found. Skipping
# Processing Record 8 of Set 10 | mujiayingzi
# Processing Record 9 of Set 10 | yenagoa
# Processing Record 10 of Set 10 | arlit
# Processing Record 11 of Set 10 | terme
# Processing Record 12 of Set 10 | grand centre
# City not found. Skipping
# Processing Record 13 of Set 10 | madingou
# Processing Record 14 of Set 10 | crossville
# Processing Record 15 of Set 10 | aki
# Processing Record 16 of Set 10 | lano
# Processing Record 17 of Set 10 | talcahuano
# Processing Record 18 of Set 10 | san luis
# Processing Record 19 of Set 10 | porosozero
# Processing Record 20 of Set 10 | kondinskoye
# Processing Record 21 of Set 10 | mercedes
# Processing Record 22 of Set 10 | trincomalee
# Processing Record 23 of Set 10 | pangai
# Processing Record 24 of Set 10 | college
# Processing Record 25 of Set 10 | voyvozh
# Processing Record 26 of Set 10 | taiyuan
# Processing Record 27 of Set 10 | muravlenko
# Processing Record 28 of Set 10 | sharjah
# Processing Record 29 of Set 10 | veraval
# Processing Record 30 of Set 10 | alpena
# Processing Record 31 of Set 10 | naftah
# City not found. Skipping
# Processing Record 32 of Set 10 | hanna
# Processing Record 33 of Set 10 | omsukchan
# Processing Record 34 of Set 10 | farmington
# Processing Record 35 of Set 10 | labuhan
# Processing Record 36 of Set 10 | kiknur
# Processing Record 37 of Set 10 | saint-georges
# Processing Record 38 of Set 10 | dubreka
# Processing Record 39 of Set 10 | mastic beach
# Processing Record 40 of Set 10 | santo estevao
# Processing Record 41 of Set 10 | takoradi
# Processing Record 42 of Set 10 | kiama
# Processing Record 43 of Set 10 | nelson bay
# Processing Record 44 of Set 10 | oktyabrskiy
# Processing Record 45 of Set 10 | kuliyapitiya
# Processing Record 46 of Set 10 | san carlos de bariloche
# Processing Record 47 of Set 10 | namtsy
# Processing Record 48 of Set 10 | johi
# Processing Record 49 of Set 10 | druskininkai
# Processing Record 50 of Set 10 | tilichiki
# Processing Record 1 of Set 11 | katherine
# Processing Record 2 of Set 11 | viksoyri
# City not found. Skipping
# Processing Record 3 of Set 11 | lyaskelya
# Processing Record 4 of Set 11 | tabuk
# Processing Record 5 of Set 11 | turbat
# Processing Record 6 of Set 11 | pedernales
# Processing Record 7 of Set 11 | fevralsk
# City not found. Skipping
# Processing Record 8 of Set 11 | humpolec
# Processing Record 9 of Set 11 | arrifes
# Processing Record 10 of Set 11 | srivardhan
# Processing Record 11 of Set 11 | valparaiso
# Processing Record 12 of Set 11 | klaksvik
# Processing Record 13 of Set 11 | codrington
# Processing Record 14 of Set 11 | paita
# Processing Record 15 of Set 11 | grand-lahou
# Processing Record 16 of Set 11 | cacapava do sul
# Processing Record 17 of Set 11 | calabozo
# Processing Record 18 of Set 11 | oistins
# Processing Record 19 of Set 11 | san jose
# Processing Record 20 of Set 11 | arman
# Processing Record 21 of Set 11 | acari
# Processing Record 22 of Set 11 | charters towers
# Processing Record 23 of Set 11 | baruun-urt
# Processing Record 24 of Set 11 | daru
# Processing Record 25 of Set 11 | dekar
# Processing Record 26 of Set 11 | anadyr
# Processing Record 27 of Set 11 | nome
# Processing Record 28 of Set 11 | borogontsy
# Processing Record 29 of Set 11 | suihua
# Processing Record 30 of Set 11 | meulaboh
# Processing Record 31 of Set 11 | hargeysa
# Processing Record 32 of Set 11 | thunder bay
# Processing Record 33 of Set 11 | karasjok
# Processing Record 34 of Set 11 | mpongwe
# Processing Record 35 of Set 11 | carutapera
# Processing Record 36 of Set 11 | alencon
# Processing Record 37 of Set 11 | lar gerd
# City not found. Skipping
# Processing Record 38 of Set 11 | kurya
# Processing Record 39 of Set 11 | richmond
# Processing Record 40 of Set 11 | alice springs
# Processing Record 41 of Set 11 | ziro
# Processing Record 42 of Set 11 | manicore
# Processing Record 43 of Set 11 | zhezkazgan
# Processing Record 44 of Set 11 | san juan
# Processing Record 45 of Set 11 | kavaratti
# Processing Record 46 of Set 11 | biak
# Processing Record 47 of Set 11 | reichenau
# Processing Record 48 of Set 11 | novobirilyussy
# Processing Record 49 of Set 11 | marienburg
# Processing Record 50 of Set 11 | north augusta
# Processing Record 1 of Set 12 | aswan
# Processing Record 2 of Set 12 | komsomolskiy
# Processing Record 3 of Set 12 | royal tunbridge wells
# Processing Record 4 of Set 12 | porto santo
# Processing Record 5 of Set 12 | ilhabela
# Processing Record 6 of Set 12 | greymouth
# Processing Record 7 of Set 12 | abong mbang
# Processing Record 8 of Set 12 | tornio
# Processing Record 9 of Set 12 | auki
# Processing Record 10 of Set 12 | qingdao
# Processing Record 11 of Set 12 | fort frances
# Processing Record 12 of Set 12 | zyryanka
# Processing Record 13 of Set 12 | tirumullaivasal
# Processing Record 14 of Set 12 | broome
# Processing Record 15 of Set 12 | darhan
# Processing Record 16 of Set 12 | pinega
# Processing Record 17 of Set 12 | uarini
# Processing Record 18 of Set 12 | nyaunglebin
# Processing Record 19 of Set 12 | jacareacanga
# Processing Record 20 of Set 12 | dumabato
# Processing Record 21 of Set 12 | kralendijk
# Processing Record 22 of Set 12 | jose bonifacio
# Processing Record 23 of Set 12 | tecoanapa
# Processing Record 24 of Set 12 | noyabrsk
# Processing Record 25 of Set 12 | kulu
# Processing Record 26 of Set 12 | muli
# Processing Record 27 of Set 12 | concepcion del uruguay
# Processing Record 28 of Set 12 | aklavik
# Processing Record 29 of Set 12 | kalga
# Processing Record 30 of Set 12 | guymon
# Processing Record 31 of Set 12 | hervey bay
# Processing Record 32 of Set 12 | cuiluan
# Processing Record 33 of Set 12 | san andres
# Processing Record 34 of Set 12 | urengoy
# Processing Record 35 of Set 12 | lasa
# Processing Record 36 of Set 12 | sioux lookout
# Processing Record 37 of Set 12 | mitsamiouli
# Processing Record 38 of Set 12 | presidente medici
# Processing Record 39 of Set 12 | vicente guerrero
# Processing Record 40 of Set 12 | saint george
# Processing Record 41 of Set 12 | nioro
# Processing Record 42 of Set 12 | matagami
# Processing Record 43 of Set 12 | cavalcante
# Processing Record 44 of Set 12 | tuy hoa
# Processing Record 45 of Set 12 | boueni
# Processing Record 46 of Set 12 | kislovodsk
# Processing Record 47 of Set 12 | henties bay
# Processing Record 48 of Set 12 | palmer
# Processing Record 49 of Set 12 | doctor pedro p. pena
# City not found. Skipping
# Processing Record 50 of Set 12 | alofi
# Processing Record 1 of Set 13 | aksu
# Processing Record 2 of Set 13 | saint-pierre
# Processing Record 3 of Set 13 | sarankhola
# Processing Record 4 of Set 13 | mocambique
# City not found. Skipping
# Processing Record 5 of Set 13 | mweka
# Processing Record 6 of Set 13 | sovetskaya gavan
# Processing Record 7 of Set 13 | halifax
# Processing Record 8 of Set 13 | amboasary
# Processing Record 9 of Set 13 | ayan
# Processing Record 10 of Set 13 | mahibadhoo
# Processing Record 11 of Set 13 | suez
# Processing Record 12 of Set 13 | mersin
# Processing Record 13 of Set 13 | agadez
# Processing Record 14 of Set 13 | itaqui
# Processing Record 15 of Set 13 | kurumkan
# Processing Record 16 of Set 13 | castletown
# Processing Record 17 of Set 13 | berdigestyakh
# Processing Record 18 of Set 13 | singkang
# Processing Record 19 of Set 13 | warqla
# City not found. Skipping
# Processing Record 20 of Set 13 | samarai
# Processing Record 21 of Set 13 | galveston
# Processing Record 22 of Set 13 | capreol
# Processing Record 23 of Set 13 | usinsk
# Processing Record 24 of Set 13 | carbondale
# Processing Record 25 of Set 13 | dingle
# Processing Record 26 of Set 13 | el retorno
# Processing Record 27 of Set 13 | sangin
# Processing Record 28 of Set 13 | brae
# Processing Record 29 of Set 13 | beauceville
# Processing Record 30 of Set 13 | vredendal
# Processing Record 31 of Set 13 | halalo
# City not found. Skipping
# Processing Record 32 of Set 13 | inderborskiy
# City not found. Skipping
# Processing Record 33 of Set 13 | kuala lipis
# Processing Record 34 of Set 13 | joquicingo
# Processing Record 35 of Set 13 | nanning
# Processing Record 36 of Set 13 | rocha
# Processing Record 37 of Set 13 | khartoum
# Processing Record 38 of Set 13 | kalabo
# Processing Record 39 of Set 13 | asfi
# Processing Record 40 of Set 13 | qibili
# City not found. Skipping
# Processing Record 41 of Set 13 | monrovia
# Processing Record 42 of Set 13 | llata
# Processing Record 43 of Set 13 | thinadhoo
# Processing Record 44 of Set 13 | camopi
# Processing Record 45 of Set 13 | mecca
# Processing Record 46 of Set 13 | broken hill
# Processing Record 47 of Set 13 | nautanwa
# Processing Record 48 of Set 13 | kontagora
# Processing Record 49 of Set 13 | aksarka
# Processing Record 50 of Set 13 | khasan
# Processing Record 1 of Set 14 | kieta
# Processing Record 2 of Set 14 | kropotkin
# Processing Record 3 of Set 14 | sulechow
# Processing Record 4 of Set 14 | mto wa mbu
# Processing Record 5 of Set 14 | toba
# Processing Record 6 of Set 14 | ban tak
# Processing Record 7 of Set 14 | honningsvag
# Processing Record 8 of Set 14 | yichun
# Processing Record 9 of Set 14 | dhidhdhoo
# Processing Record 10 of Set 14 | cascais
# Processing Record 11 of Set 14 | sorada
# Processing Record 12 of Set 14 | sumbawa
# City not found. Skipping
# Processing Record 13 of Set 14 | la ronge
# Processing Record 14 of Set 14 | lagdo
# Processing Record 15 of Set 14 | san felipe
# Processing Record 16 of Set 14 | harper
# Processing Record 17 of Set 14 | kijang
# Processing Record 18 of Set 14 | komatsu
# Processing Record 19 of Set 14 | burica
# City not found. Skipping
# Processing Record 20 of Set 14 | hovd
# Processing Record 21 of Set 14 | yulara
# Processing Record 22 of Set 14 | rorvik
# Processing Record 23 of Set 14 | puerto escondido
# Processing Record 24 of Set 14 | rio claro
# Processing Record 25 of Set 14 | svetlogorsk
# Processing Record 26 of Set 14 | ust-omchug
# Processing Record 27 of Set 14 | ovalle
# Processing Record 28 of Set 14 | pandamatenga
# Processing Record 29 of Set 14 | adrar
# Processing Record 30 of Set 14 | wum
# Processing Record 31 of Set 14 | ak-dovurak
# Processing Record 32 of Set 14 | bosaso
# Processing Record 33 of Set 14 | tanggu
# Processing Record 34 of Set 14 | laguna
# Processing Record 35 of Set 14 | saint-augustin
# Processing Record 36 of Set 14 | newton
# Processing Record 37 of Set 14 | fare
# Processing Record 38 of Set 14 | dunedin
# Processing Record 39 of Set 14 | maniitsoq
# Processing Record 40 of Set 14 | dubbo
# Processing Record 41 of Set 14 | rogun
# City not found. Skipping
# Processing Record 42 of Set 14 | dryden
# Processing Record 43 of Set 14 | boatlaname
# City not found. Skipping
# Processing Record 44 of Set 14 | necochea
# Processing Record 45 of Set 14 | sibu
# Processing Record 46 of Set 14 | kopavogur
# Processing Record 47 of Set 14 | puro
# Processing Record 48 of Set 14 | monte alegre
# Processing Record 49 of Set 14 | bani walid
# Processing Record 50 of Set 14 | ternate
# Processing Record 1 of Set 15 | nago
# Processing Record 2 of Set 15 | cedar lake
# Processing Record 3 of Set 15 | kahta
# Processing Record 4 of Set 15 | la rioja
# Processing Record 5 of Set 15 | fairbanks
# Processing Record 6 of Set 15 | nicoya
# Processing Record 7 of Set 15 | kuche
# City not found. Skipping
# Processing Record 8 of Set 15 | vrangel
# Processing Record 9 of Set 15 | tarifa
# Processing Record 10 of Set 15 | ippy
# Processing Record 11 of Set 15 | srednekolymsk
# Processing Record 12 of Set 15 | phan rang
# City not found. Skipping
# Processing Record 13 of Set 15 | hami
# Processing Record 14 of Set 15 | miri
# Processing Record 15 of Set 15 | popondetta
# Processing Record 16 of Set 15 | kerman
# Processing Record 17 of Set 15 | planadas
# Processing Record 18 of Set 15 | paamiut
# Processing Record 19 of Set 15 | olafsvik
# Processing Record 20 of Set 15 | sumenep
# Processing Record 21 of Set 15 | te anau
# Processing Record 22 of Set 15 | ibra
# Processing Record 23 of Set 15 | hulan
# Processing Record 24 of Set 15 | ewa beach
# Processing Record 25 of Set 15 | ketchikan
# Processing Record 26 of Set 15 | amarante do maranhao
# Processing Record 27 of Set 15 | durazno
# Processing Record 28 of Set 15 | acarau
# Processing Record 29 of Set 15 | santa cruz de la palma
# Processing Record 30 of Set 15 | clarence town
# Processing Record 31 of Set 15 | wamba
# Processing Record 32 of Set 15 | kabwe
# Processing Record 33 of Set 15 | aviles
# Processing Record 34 of Set 15 | acapulco
# Processing Record 35 of Set 15 | shushtar
# Processing Record 36 of Set 15 | neuquen
# Processing Record 37 of Set 15 | gravdal
# Processing Record 38 of Set 15 | san borja
# Processing Record 39 of Set 15 | sorrento
# Processing Record 40 of Set 15 | roanoke
# Processing Record 41 of Set 15 | roros
# Processing Record 42 of Set 15 | kerteh
# City not found. Skipping
# Processing Record 43 of Set 15 | kutum
# Processing Record 44 of Set 15 | colares
# Processing Record 45 of Set 15 | eldikan
# City not found. Skipping
# Processing Record 46 of Set 15 | bintulu
# Processing Record 47 of Set 15 | riyadh
# Processing Record 48 of Set 15 | sainte-marie
# Processing Record 49 of Set 15 | vreed en hoop
# City not found. Skipping
# Processing Record 50 of Set 15 | bay roberts
# Processing Record 1 of Set 16 | grand-santi
# Processing Record 2 of Set 16 | nizhniy kuranakh
# Processing Record 3 of Set 16 | high prairie
# Processing Record 4 of Set 16 | maykor
# Processing Record 5 of Set 16 | kampong thum
# Processing Record 6 of Set 16 | alekseyevka
# Processing Record 7 of Set 16 | ginda
# Processing Record 8 of Set 16 | beipiao
# Processing Record 9 of Set 16 | pangkalanbuun
# Processing Record 10 of Set 16 | freetown
# Processing Record 11 of Set 16 | scarborough
# Processing Record 12 of Set 16 | camacha
# Processing Record 13 of Set 16 | cairo
# Processing Record 14 of Set 16 | kjopsvik
# Processing Record 15 of Set 16 | tommot
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 711

# %%
#add the data to a list in a dictionary then at df
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0           Kuito      AO  2022-07-15 23:28:21 -12.3833   16.9333     52.70
# 1      Butaritari      KI  2022-07-15 23:28:21   3.0707  172.7902     81.99
# 2           Bluff      NZ  2022-07-15 23:28:21 -46.6000  168.3333     35.80
# 3         Ushuaia      AR  2022-07-15 23:25:07 -54.8000  -68.3000     35.26
# 4      Sao Filipe      CV  2022-07-15 23:28:22  14.8961  -24.4956     74.79
# 5           Kapaa      US  2022-07-15 23:28:22  22.0752 -159.3190     84.18
# 6        Bengkulu      ID  2022-07-15 23:28:22  -3.8004  102.2655     75.52
# 7     Clyde River      CA  2022-07-15 23:28:23  70.4692  -68.5914     55.63
# 8  Ribeira Grande      PT  2022-07-15 23:28:23  38.5167  -28.7000     70.30
# 9       Hithadhoo      MV  2022-07-15 23:28:23  -0.6000   73.0833     83.61
#
#    Humidity  Cloudiness  Wind Speed Current Description
# 0        44           0        3.40           clear sky
# 1        80         100       19.80       moderate rain
# 2        75          82       19.28       broken clouds
# 3        60          20        9.22          few clouds
# 4        80         100        5.39     overcast clouds
# 5        67          20       13.80          few clouds
# 6        88         100        4.27       moderate rain
# 7        47           0       14.97           clear sky
# 8        89          55        8.37       broken clouds
# 9        73          78       15.75       broken clouds

# %%
# Create CSV file of DF
csv_weather_file = "weatherpy_database.csv"
# Export CSV file 
city_data_df.to_csv(csv_weather_file, index_label="City_ID")
