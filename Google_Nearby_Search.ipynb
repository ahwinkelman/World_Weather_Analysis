# %%
# Dependencies and Setup
import requests
import gmaps

# Import API key
from config import g_key

# %%
# Set the parameters to search for a hotel in Paris.
params = {
    "radius": 5000,
    "types": "lodging",
    "key": g_key,
    "location": "48.8566, 2.3522"}
# Use base URL to search for hotels in Paris.
base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

#print(base_url)
# Make request and get the JSON data from the search.
hotels = requests.get(base_url, params=params).json()
print(hotels)
#hotels
# Out:
# {'html_attributions': [], 'next_page_token': 'AeJbb3d5LPCrcJ0yy_AD-rNjunSJ2pnropVu03Eu_FC5t7_dd-KH7fjZhaHwNniW5aqyd_Jb7KZ8Zg6BIj0ybHnU472xp4g0atxiIv4R_1cx9p9rowTFuRqMEKYMTXjfyCu8gdasPXL5vU953YOuS-Bq5irSNIGqsM3Cha-8CclodBzL3Moive6fMCMbEIIU8gxg1PZkqGWRTQ_9YbU3mfFhV3sqVS6UjCoMgZT37OW_Ec93wqA6-kjOig2kjKZgD0vzMq5o1X1NOTwwcKy5-KVO66Zru0rT4fXRLJdXfge8HfNfCNCE2juxVKxLFpfIfXacbuLwXKDCaQSHu7Y87khEXvQm-723uk9W50TFiU4-rkJA5hizjQ5n5019X34oFVqxw9uPbJXgKnFmOaw64srT5oVtoPyQy1PTEDuXVZLMB5ZASvyUk3LPAzz2', 'results': [{'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8581126, 'lng': 2.3529277}, 'viewport': {'northeast': {'lat': 48.8594360302915, 'lng': 2.354355480291502}, 'southwest': {'lat': 48.8567380697085, 'lng': 2.351657519708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Hôtel Duo', 'opening_hours': {'open_now': True}, 'photos': [{'height': 3840, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107554201425443337224">Hôtel Duo</a>'], 'photo_reference': 'AeJbb3dVOa0SoiwdxfMojO4waQ5mgnixcqJGKG25O0uhaQLxvj71ahkVzDxC9i5ShLuQ3WaRmC3glinw4W_e59lkmr977rP5XEtJWQUNDYCCEb97VwLwOdJvbtfBsUi0yyn7PIFwxOGbbdrH6Heh4rthWNuiqiQpb_eS_sYTve8J9I3Xq4Tr', 'width': 5760}], 'place_id': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc', 'plus_code': {'compound_code': 'V953+65 Paris, France', 'global_code': '8FW4V953+65'}, 'rating': 4.2, 'reference': 'ChIJWU9CqB1u5kcR5P1F2SMoJmc', 'scope': 'GOOGLE', 'types': ['night_club', 'bar', 'gym', 'spa', 'lodging', 'health', 'point_of_interest', 'establishment'], 'user_ratings_total': 336, 'vicinity': '11 Rue du Temple, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8582861, 'lng': 2.3464944}, 'viewport': {'northeast': {'lat': 48.85954748029151, 'lng': 2.347782830291502}, 'southwest': {'lat': 48.85684951970851, 'lng': 2.345084869708498}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Britannique Hotel - Paris Centre', 'opening_hours': {'open_now': True}, 'photos': [{'height': 1426, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108984000175492464929">Hôtel Britannique - Paris Centre</a>'], 'photo_reference': 'AeJbb3eFHwJ9FmfjkxnTpkummhgCoIfFEjWXNSyiasJL5Gx4Pac3CoygdZe5iFhGCXW0xYbGhuWPTOeOJb-yPjcC9ecwWnxFnyG3f5HoETwun-prc6PsdFjLqzgLA8jbAU1BPdGYhc1RbA0AtPhSm7fD-vaglqWuq8FUvjTiRAXRBsiKHkug', 'width': 1476}], 'place_id': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU', 'plus_code': {'compound_code': 'V85W+8H Paris, France', 'global_code': '8FW4V85W+8H'}, 'rating': 4.7, 'reference': 'ChIJ-4Siox9u5kcRm9vM6DcMXyU', 'scope': 'GOOGLE', 'types': ['lodging', 'point_of_interest', 'establishment'], 'user_ratings_total': 750, 'vicinity': '20 Avenue Victoria, Paris'}, {'business_status': 'OPERATIONAL', 'geometry': {'location': {'lat': 48.8606342, 'lng': 2.3468978}, 'viewport': {'northeast': {'lat': 48.8617746302915, 'lng': 2.347927730291502}, 'southwest': {'lat': 48.8590766697085, 'lng': 2.345229769708499}}}, 'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/lodging-71.png', 'icon_background_color': '#909CE1', 'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/hotel_pinlet', 'name': 'Citadines Les Halles Paris', 'opening_hours': {'open_now': True}, 'photos': [{'height': 853, 'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102565262508115704337">Citadines Apart&#39;hotel Les Halles Paris</a>'], 'photo_reference': 'AeJbb3eSXmld_MlgrGDBcvdWelmQXyYcuqCg9u-RDoODSTEpQ5eqwQ6Sdhbdup__deMW1ZwgrFM7c7sqb1qkv9K4lke8W-8qYHvbvaQfKhiD_wYXmU6WE0hZ7h6d0eA_D-jJcvMAMTWhcBRMRPxKmPcGfYz3cNJd6syPtIx159NPQljXGwi6', 'width': 1280}], 'place_id': 'ChIJQ_QDrxhu5kcRJzNxLLEOSfU', 'plus_code': {'c ...

# %%
len(hotels["results"])
# Out:
# 20

# %%
# Iterate through the DataFrame.
for index, row in hotel_df.iterrows():
    # Get the latitude and longitude.
    lat = row["Lat"]
    lng = row["Lng"]

    # Add the latitude and longitude to location key for the params dictionary.
    params["location"] = f"{lat},{lng}"

    # Use the search term: "lodging" and our latitude and longitude.
    base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
    # Make request and get the JSON data from the search.
    hotels = requests.get(base_url, params=params).json()
    # Grab the first hotel from the results and store the name.
    hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5708\3718543742.py in <module>
#       1 # Iterate through the DataFrame.
# ----> 2 for index, row in hotel_df.iterrows():
#       3     # Get the latitude and longitude.
#       4     lat = row["Lat"]
#       5     lng = row["Lng"]
#
# NameError: name 'hotel_df' is not defined
